# %%
from __future__ import print_function
import os
import zipfile
import plaidml.keras
plaidml.keras.install_backend()
import keras

# %%
import numpy as np
import pandas as pd
from collections import Counter
from datetime import datetime

# %%
dataRaw = pd.read_csv("Dataset/train.csv")

# %%
dataRaw.head(100)
# Out:
#         pet_id           issue_date         listing_date  condition  \
# 0   ANSL_69903  2016-07-10 00:00:00  2016-09-21 16:25:00        2.0
# 1   ANSL_66892  2013-11-21 00:00:00  2018-12-27 17:47:00        1.0
# 2   ANSL_69750  2014-09-28 00:00:00  2016-10-19 08:24:00        NaN
# 3   ANSL_71623  2016-12-31 00:00:00  2019-01-25 18:30:00        1.0
# 4   ANSL_57969  2017-09-28 00:00:00  2017-11-19 09:38:00        2.0
# ..         ...                  ...                  ...        ...
# 95  ANSL_70120  2014-06-24 00:00:00  2018-01-19 18:19:00        1.0
# 96  ANSL_71504  2016-07-04 00:00:00  2016-11-25 18:46:00        0.0
# 97  ANSL_71993  2012-07-21 00:00:00  2017-08-05 17:34:00        0.0
# 98  ANSL_69762  2013-12-27 00:00:00  2018-10-05 15:59:00        0.0
# 99  ANSL_59393  2018-07-19 00:00:00  2018-12-23 19:15:00        1.0
#
#       color_type  length(m)  height(cm)  X1  X2  breed_category  pet_category
# ...

# %%
a=AugData.count(level="height")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-64ecc0aeb107> in <module>
# ----> 1 a=AugData.count(level="height")
#
# c:\users\sachi\anaconda3\envs\tensorenv1\lib\site-packages\pandas\core\frame.py in count(self, axis, level, numeric_only)
#    8448         axis = self._get_axis_number(axis)
#    8449         if level is not None:
# -> 8450             return self._count_level(level, axis=axis, numeric_only=numeric_only)
#    8451
#    8452         if numeric_only:
#
# c:\users\sachi\anaconda3\envs\tensorenv1\lib\site-packages\pandas\core\frame.py in _count_level(self, level, axis, numeric_only)
#    8484         if not isinstance(count_axis, MultiIndex):
#    8485             raise TypeError(
# -> 8486                 f"Can only count levels on hierarchical {self._get_axis_name(axis)}."
#    8487             )
#    8488
#
# ...

# %%
a
# Out:
# pet_id            18834
# issue_date        18834
# listing_date      18834
# condition         17357
# color_type        18834
# length(m)         18834
# height(cm)        18834
# X1                18834
# X2                18834
# breed_category    18834
# pet_category      18834
# dtype: int64

# %%
AugData = dataRaw

# %%
AugData["sample_weight"] = 1/118834

# %%
AugData
# Out:
#            pet_id           issue_date         listing_date  condition  \
# 0      ANSL_69903  2016-07-10 00:00:00  2016-09-21 16:25:00        2.0
# 1      ANSL_66892  2013-11-21 00:00:00  2018-12-27 17:47:00        1.0
# 2      ANSL_69750  2014-09-28 00:00:00  2016-10-19 08:24:00        1.0
# 3      ANSL_71623  2016-12-31 00:00:00  2019-01-25 18:30:00        1.0
# 4      ANSL_57969  2017-09-28 00:00:00  2017-11-19 09:38:00        2.0
# ...           ...                  ...                  ...        ...
# 18829  ANSL_51738  2017-01-26 00:00:00  2018-03-09 15:35:00        2.0
# 18830  ANSL_59900  2016-06-18 00:00:00  2017-07-09 08:37:00        1.0
# 18831  ANSL_53210  2010-07-21 00:00:00  2018-08-22 14:27:00        0.0
# 18832  ANSL_63468  2017-05-12 00:00:00  2018-02-08 14:05:00        0.0
# 18833  ANSL_73558  2011-12-13 00:00:00  2018-10-26 14:18:00        0.0
#
#          color_type  length(m)  height(cm)  X1  X2  breed_category  \
# ...

# %%
meanOfCondition=(dataRaw["condition"]).mean()
dataRaw["condition"].fillna(np.around(meanOfCondition),inplace=True)

# %%
dataRaw
# Out:
#            pet_id           issue_date         listing_date  condition  \
# 0      ANSL_69903  2016-07-10 00:00:00  2016-09-21 16:25:00        2.0
# 1      ANSL_66892  2013-11-21 00:00:00  2018-12-27 17:47:00        1.0
# 2      ANSL_69750  2014-09-28 00:00:00  2016-10-19 08:24:00        1.0
# 3      ANSL_71623  2016-12-31 00:00:00  2019-01-25 18:30:00        1.0
# 4      ANSL_57969  2017-09-28 00:00:00  2017-11-19 09:38:00        2.0
# ...           ...                  ...                  ...        ...
# 18829  ANSL_51738  2017-01-26 00:00:00  2018-03-09 15:35:00        2.0
# 18830  ANSL_59900  2016-06-18 00:00:00  2017-07-09 08:37:00        1.0
# 18831  ANSL_53210  2010-07-21 00:00:00  2018-08-22 14:27:00        0.0
# 18832  ANSL_63468  2017-05-12 00:00:00  2018-02-08 14:05:00        0.0
# 18833  ANSL_73558  2011-12-13 00:00:00  2018-10-26 14:18:00        0.0
#
#          color_type  length(m)  height(cm)  X1  X2  breed_category  \
# ...
